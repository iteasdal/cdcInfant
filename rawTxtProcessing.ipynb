# %%
'''
4 January 2019
This file is designed for processing the CDC LinkCO11US and LinkCO12US numerator files.
The field names are consistent with the CDC data dictionary.
The commented out fields are because the fields contain exclusively or almost exclusively null values.
Renamed the cdc files to .txt extension.
The demoninator files, are too large for my humble machine to process. Need to add that at some point.

Currently set up to process one file at a time. Just uncomment the filepath line at the beginning and the corresponding df.to_csv at the end.

'''

import os
import pandas as pd

#filePath = '/Users/ateasdale/personal/2019/infantMortality/cdcData/birthCohortLinkedBirthInfantDeath/LinkCO12US/VS12LKBCnum.txt'
#filePath = '/Users/ateasdale/personal/2019/infantMortality/cdcData/birthCohortLinkedBirthInfantDeath/LinkCO11US/VS11LKBCnum.txt'

# Input
data_file = filePath

# Delimiter: originally, the delimiter was a ' '. Changed to pipe to just have one field.
data_file_delimiter = '|'

# The max column count a line in the file could have
largest_column_count = 0

# Loop the data lines
with open(data_file, 'r') as temp_f:
    # Read the lines
    lines = temp_f.readlines()

    for l in lines:
        # Count the column count for the current line
        column_count = len(l.split(data_file_delimiter)) + 1

        # Set the new most column count
        largest_column_count = column_count if largest_column_count < column_count else largest_column_count

# Close file
temp_f.close()

# Generate column names (will be 0, 1, 2, ..., largest_column_count - 1)
column_names = [i for i in range(1, largest_column_count)]

# Read csv
df = pd.read_csv(data_file, header=None, delimiter=data_file_delimiter, names=column_names)

# If the file is a numerator file, indicate with 1, 0 if not.


'''
# adding a field to indicate whether the record comes from the numerator file
if filePath[-7:] == "num.txt":
    df['numerator'] = 1
else:
    df['numerator'] = 0
'''

df['VERSION'] = df[1].str[6:7]
#df['LATEREC'] = df[1].str[8:9] #All records are 0
df['SEQNUM'] = df[1].str[9:14]
df['DOB_YY'] = df[1].str[14:18]
df['DOB_MM'] = df[1].str[18:20]
#df['DOB_TT'] = df[1].str[24:28]
df['DOB_WK'] = df[1].str[28:29] #1 Sunday, 2 Monday, ...
#df['OSTATE'] = df[1].str[29:31] #Gu-Guam, PR-Puerto Rico, VI-Virgin Islands
#df['OCNTYFIPS'] = df[1].str[36:39] #Only in territory.
#df['OCNTYPOP'] = df[1].str[39:40] #Only in territory. 0- >1,000,000, 1- 500k to 1m, 2- 250k to 500k, 9- <250k
#df['BFACIL'] = df[1].str[40:41]
df['UBFACIL'] = df[1].str[41:42] #1-Hospital, 2-Freestanding Birth Center, 3-Home (intended), 4-Home (unintended)
# 5-Home (intent unknown), 6-Clinic/Doctor's office, 7-other, 9-unknown
df['BFACIL3'] = df[1].str[58:59] #Birthplace recode 1-Hospital, 2-not hospital, 3-unknown/not stated
#df['MAGE_IMPFLG'] = df[1].str[86:87] #blank-not imputed, 1-imputed
#df['MAGE_REPFLG'] = df[1].str[87:88] #blank-reported age not used, 1-reported age used
df['MAGER'] = df[1].str[88:90] #12- 10-12 years, rest actual age
df['MAGER14'] = df[1].str[90:92] # 01- <15, 03- 15, 04- 16, 05- 17, 06- 18, 07- 19, 08- 20-24, etc.
df['MAGER9'] = df[1].str[92:93] # 1- <15, 2- 15-19, 3- 20-24, 4- 25-29, etc.
#df['MBCNTRY'] = df[1].str[93:95]
#df['MRSTATEPSTL'] = df[1].str[108:110] #territory only
#df['MRCNTY'] = df[1].str[113:116] #territory only
#df['RCNTY_POP'] = df[1].str[131:132] #territory only
#df['RECTYPE'] = df[1].str[136:137] #territory only
df['RESTATUS'] = df[1].str[137:138] #1-resident, 2-occurrence and res. same but diff county, 3 - diff state, etc.
df['MBRACE'] = df[1].str[138:140] #see guide
df['MRACE'] = df[1].str[140:142] #see guide
df['MRACEREC'] = df[1].str[142:143] #blank - not imputed, 1 - unknown, 2 - all other
#df['MRACEIMP'] = df[1].str[143:144]
df['UMHISP'] = df[1].str[147:148] #see guide
df['MRACEHISP'] = df[1].str[148:149] #see guide
#df['MAR_P'] = df[1].str[151:152] #Y-yes, N-no, U-unknown, X-Not applicable
df['MAR'] = df[1].str[152:153] #1-yes, 2-no, 9-unknown/not stated
#df['MAR_IMP'] = df[1].str[153:154] #blank-not imputed, 1-imputed
df['MEDUC'] = df[1].str[154:155] #see guide
#df['FAGERPT_FLG'] = df[1].str[174:175] #blank-not used, 1-used
#df['FAGECOMB'] = df[1].str[181:183] #09-98, 99-unknown/not stated
#df['UFAGECOMB'] = df[1].str[183:185] #10-98, 99-unknown/not stated
df['FAGEREC11'] = df[1].str[185:187] #see guide
df['FBRACE'] = df[1].str[187:189] #see guide
df['FRACEREC'] = df[1].str[190:191] #see guide
df['UFHISP'] = df[1].str[194:195] #see guide
df['FRACEHISP'] = df[1].str[195:196] #see guide
df['FEDUC'] = df[1].str[196:197]
df['UFRACE'] = df[1].str[198:200]
df['PRIORTERM'] = df[1].str[207:209]
df['LBO_REC'] = df[1].str[211:212]
df['TBO_REC'] = df[1].str[216:217]
#df['PRECARE'] = df[1].str[244:246]
#df['PRECARE_REC'] = df[1].str[246:247]
df['UPREVIS'] = df[1].str[269:271]
df['PREVIS_REC'] = df[1].str[271:273]
df['WTGAIN'] = df[1].str[275:277]
df['WTGAIN_REC'] = df[1].str[277:278]
#df['DFPC_IMP'] = df[1].str[279:280]
#df['WIC'] = df[1].str[280:281]
df['CIG_0'] = df[1].str[281:283]
df['CIG_1'] = df[1].str[283:285]
df['CIG_2'] = df[1].str[285:287]
df['CIG_3'] = df[1].str[287:289]
df['CIG_REC'] = df[1].str[293:294]
#df['RF_DIAB'] = df[1].str[312:313]
#df['RF_GEST'] = df[1].str[313:314]
#df['RF_PHYP'] = df[1].str[314:315]
#df['RF_GHYP'] = df[1].str[315:316]
#df['RF_ECLAM'] = df[1].str[316:317]
#df['RF_PPTERM'] = df[1].str[317:318]
#df['RF_PPOUTC'] = df[1].str[318:319]
#df['RF_INFTR'] = df[1].str[320:321]
#df['RF_FEDRG']  = df[1].str[321:322]
#df['RF_ARTEC'] = df[1].str[322:323]
#df['RF_CESAR'] = df[1].str[323:324]
#df['RF_CEASRN'] = df[1].str[324:326]
df['URF_DIAB'] = df[1].str[330:331]
df['URF_CHYPER'] = df[1].str[334:335]
df['URF_PHYPER'] = df[1].str[335:336]
df['URF_ECLAM'] = df[1].str[336:337]
#df['IP_GONN'] = df[1].str[344:345]
#df['IP_SYPH'] = df[1].str[345:346]
#df['IP_CHLAM'] = df[1].str[347:348]
#df['IP_HEPB'] = df[1].str[348:349]
#df['IP_HEPC'] = df[1].str[349:350]
#df['OP_CERV'] = df[1].str[350:351]
#df['OP_TOCOL'] = df[1].str[351:352]
#df['OP_ECVS'] = df[1].str[352:353]
#df['OP_ECVF'] = df[1].str[353:354]
df['UOP_INDUC'] = df[1].str[356:357]
df['UOP_TOCOL'] = df[1].str[358:359]
#df['On_RUPTR'] = df[1].str[361:362]
#df['On_PRECIP'] = df[1].str[362:363]
#df['On_PROL'] = df[1].str[363:364]
#df['LD_INDL'] = df[1].str[364:365]
#df['LD_AUGM'] = df[1].str[365:366]
#df['LD_STER'] = df[1].str[367:368]
#df['LD_ANTI'] = df[1].str[368:369]
#df['LD_CHOR'] = df[1].str[369:370]
#df['LD_MECS'] = df[1].str[370:371]
#df['LD_FINT'] = df[1].str[371:372]
#df['LD_ANES'] = df[1].str[372:373]
df['ULD_MECO'] = df[1].str[374:375]
df['ULD_PRECIP'] = df[1].str[380:381]
df['ULD_BREECH'] = df[1].str[383:384]
df['ME_PRES'] = df[1].str[391:392]
df['ME_ROUT'] = df[1].str[392:393]
df['ME_TRIAL'] = df[1].str[393:394]
df['UME_FORCP'] = df[1].str[398:399]
df['UME_VAC'] = df[1].str[399:400]
df['DMETH_REC'] = df[1].str[402:403]
#df['MM_MTR'] = df[1].str[403:404]
#df['MM_PLAC'] = df[1].str[404:405]
#df['MM_RUPT'] = df[1].str[405:406]
#df['MM_UHYST'] = df[1].str[406:407]
#df['MM_ICU'] = df[1].str[407:408]
#df['MM_UOPER'] = df[1].str[408:409]
df['ATTEND'] = df[1].str[409:410]
df['MTRAN'] = df[1].str[410:411]
#df['PAY'] = df[1].str[411:412]
#df['PAYR'] = df[1].str[412:413]
df['APGAR5'] = df[1].str[414:415]
df['APGAR5R'] = df[1].str[416:417]
#df['APGAR10'] = df[1].str[417:418]
#df['APGAR10R'] = df[1].str[419:420]
df['DPLURAL'] = df[1].str[422:423]
#df['IMP_PLUR'] = df[1].str[424:425] #all null but 5 rows
df['SEX'] = df[1].str[435:436]
#df['IMP_SEX'] = df[1].str[436:437]
df['DLMP_MM'] = df[1].str[437:439]
df['DLMP_YY'] = df[1].str[441:445]
df['ESTGEST'] = df[1].str[445:447]
df['COMBGEST'] = df[1].str[450:452]
df['GESTREC10'] = df[1].str[452:454]
df['OBGEST_FLG'] = df[1].str[455:456]
df['GEST_IMP'] = df[1].str[456:457]
df['BRTHWGT'] = df[1].str[466:470]
df['BWTR14'] = df[1].str[470:472]
df['BWTR4'] = df[1].str[472:473]
'''
df['AB_AVEN1'] = df[1].str[475:476]
df['AB_AVEN6'] = df[1].str[476:477]
df['AB_NICU'] = df[1].str[477:478]
df['AB_SURF'] = df[1].str[478:479]
df['AB_ANTI'] = df[1].str[479:480]
df['AB_SEIZ'] = df[1].str[480:481]
df['AB_BINJ'] = df[1].str[481:482]
df['CA_ANEN'] = df[1].str[491:492]
df['CA_MNSB'] = df[1].str[492:493]
df['CA_CCHD'] = df[1].str[493:494]
df['CA_CDH'] = df[1].str[494:495]
df['CA_OMPH'] = df[1].str[495:496]
df['CA_GAST'] = df[1].str[496:497]
df['CA_LIMB'] = df[1].str[497:498]
df['CA_CLEFT'] = df[1].str[498:499]
df['CA_CLPAL'] = df[1].str[499:500]
df['CA_DOWN'] = df[1].str[500:501]
df['CA_DISOR'] = df[1].str[501:502]
df['CA_HYPO'] = df[1].str[502:503]
'''
df['UCA_ANEN'] = df[1].str[503:504]
df['UCA_SPINA'] = df[1].str[504:505]
df['UCA_OMPHA'] = df[1].str[512:513]
df['UCA_CELFTLP'] = df[1].str[517:518]
df['UCA_HERNIA'] = df[1].str[520:521]
df['UCA_DOWNS'] = df[1].str[522:523]
'''
df['ITRAN'] = df[1].str[525:526]
df['ILIVE'] = df[1].str[526:527]
df['BFED'] = df[1].str[527:528]
df['BMI_R'] = df[1].str[532:533]
df['ILLB_R'] = df[1].str[533:536]
df['ILLB_R11'] = df[1].str[536:538]
df['ILOP_R'] = df[1].str[538:541]
df['ILOP'] = df[1].str[541:543]
df['ILP'] = df[1].str[543:546]
df['ILP_R11'] = df[1].str[546:548]
df['PWgt_R'] = df[1].str[548:551]
df['DWgt_R'] = df[1].str[551:554]
df['M_Ht_In'] = df[1].str[554:556]
df['SetOrder_R'] = df[1].str[556:557]
'''
df['F_MORIGIN'] = df[1].str[568:569]
df['F_FORIGIN'] = df[1].str[569:570]
df['F_MEDUC'] = df[1].str[570:571]
df['F_FEDUC'] = df[1].str[571:572]
df['F_CLINEST'] = df[1].str[572:573]
df['F_APGAR5'] = df[1].str[573:574]
df['F_TOBACO'] = df[1].str[574:575]
df['F_M_HT'] = df[1].str[575:576]
df['F_PWGT'] = df[1].str[576:577]
df['F_DWGT'] = df[1].str[577:578]
df['F_WIC'] = df[1].str[578:579]
df['F_PAY'] = df[1].str[579:580]
df['F_BFED'] = df[1].str[580:581]
df['F_RF_PDIAB'] = df[1].str[581:582]
df['F_RF_GDIAB'] = df[1].str[582:583]
df['F_RF_PHYPER'] = df[1].str[583:584]
df['F_RF_GHYPER'] = df[1].str[584:585]
df['F_RF_ECLAMP'] = df[1].str[585:586]
df['F_RF_PPB'] = df[1].str[586:587]
df['F_RF_PPO'] = df[1].str[587:588]
df['F_RF_INFT'] = df[1].str[589:590]
df['F_RF_INFT_DRG'] = df[1].str[590:591]
df['F_RF_INF_ART'] = df[1].str[591:592]
df['F_RF_CESAR'] = df[1].str[592:593]
df['F_RF_NCESAR'] = df[1].str[593:594]
df['F_IP_GONOR'] = df[1].str[594:595]
df['F_IP_SYPH'] = df[1].str[595:596]
df['F_IP_CHLAM'] = df[1].str[597:598]
df['F_IP_HEPATB'] = df[1].str[598:599]
df['F_IP_HEPATC'] = df[1].str[599:600]
df['F_OB_CERVIC'] = df[1].str[600:601]
df['F_OB_TOCO'] = df[1].str[601:602]
df['F_OB_SUCC'] = df[1].str[602:603]
df['F_OB_FAIL'] = df[1].str[603:604]
df['F_OL_RUPTURE'] = df[1].str[604:605]
df['F_OL_PRECIP'] = df[1].str[605:606]
df['F_OL_PROLONG'] = df[1].str[606:607]
df['F_LD_INDUCT'] = df[1].str[607:608]
df['F_LD_AUGMENT'] = df[1].str[608:609]
df['F_LD_STEROIDS'] = df[1].str[610:611]
df['F_LD_ANTIBIO'] = df[1].str[611:612]
df['F_LD_CHORIO'] = df[1].str[612:613]
df['F_LD_MECON'] = df[1].str[613:614]
df['F_LD_FINTOL'] = df[1].str[614:615]
df['F_LD_ANESTH'] = df[1].str[615:616]
df['F_MD_PRESENT'] = df[1].str[618:619]
df['F_MD_ROUTE'] = df[1].str[619:620]
df['F_MD_TRIAL'] = df[1].str[620:621]
df['F_MM_MTRANS'] = df[1].str[621:622]
df['F_MM_LACER'] = df[1].str[622:623]
df['F_MM_RUPTUR'] = df[1].str[623:624]
df['F_MM_UHYSTR'] = df[1].str[624:625]
df['F_MM_ICU'] = df[1].str[625:626]
df['F_MM_OR'] = df[1].str[626:627]
df['F_AB_VENT'] = df[1].str[627:628]
df['F_AB_VENT6'] = df[1].str[628:629]
df['F_AB_NICU'] = df[1].str[629:630]
df['F_AB_SURFAC'] = df[1].str[630:631]
df['F_AB_ANTIBIO'] = df[1].str[631:632]
df['F_AB_SEIZ'] = df[1].str[632:633]
df['F_AB_INJ'] = df[1].str[633:634]
df['F_CA_ANEN'] = df[1].str[634:635]
df['F_CA_MENIN'] = df[1].str[635:636]
df['F_CA_HEARN'] = df[1].str[636:637]
df['F_CA_HERNIA'] = df[1].str[637:638]
df['F_CA_OMPHA'] = df[1].str[638:639]
df['F_CA_GASTRO'] = df[1].str[639:640]
df['F_CA_LIMB'] = df[1].str[640:641]
df['F_CA_CLEFTLP'] = df[1].str[641:642]
df['F_CA_CLEFT'] = df[1].str[642:643]
df['F_CA_DOWNS'] = df[1].str[643:644]
df['F_CA_CHROM'] = df[1].str[644:645]
df['F_CA_HYPOS'] = df[1].str[645:646]
df['F_WTGAIN'] = df[1].str[647:648]
df['F_MAR_G'] = df[1].str[651:652]
df['F_MAR_P'] = df[1].str[652:653]
df['F_MPCB'] = df[1].str[667:668]
df['F_TPCV'] = df[1].str[670:671]
df['F_CIGS0'] = df[1].str[671:672]
df['F_CIGS1'] = df[1].str[672:673]
df['F_CIGS2'] = df[1].str[673:674]
df['F_CIGS3'] = df[1].str[674:675]
df['F_FACILITY'] = df[1].str[675:676]
df['F_PAY_REC'] = df[1].str[677:678]
df['F_RDMETH_REC'] = df[1].str[678:679]
df['F_URF_DIABETES'] = df[1].str[683:684]
df['F_URF_CHYPER'] = df[1].str[687:688]
df['F_URF_PHYPER'] = df[1].str[688:689]
df['F_URF_ECLAMP'] = df[1].str[689:690]
df['F_UOB_INDUCT'] = df[1].str[702:703]
df['F_UOB_TOCOL'] = df[1].str[704:705]
df['F_ULD_MECONIUM'] = df[1].str[711:712]
df['F_ULD_PRECIP'] = df[1].str[717:718]
df['FULD_BREECH'] = df[1].str[720:721]
df['F_U_FORCEP'] = df[1].str[733:734]
df['F_U_VACUUM'] = df[1].str[734:735]
df['F_UCA_ANEN'] = df[1].str[751:752]
df['F_UCA_SPINA'] = df[1].str[752:753]
df['F_UCA_OMPHALO'] = df[1].str[760:761]
df['F_UCA_CLEFTLP'] = df[1].str[765:766]
df['F_UCA_HERNIA'] = df[1].str[768:769]
df['F_UCA_DOWNS'] = df[1].str[770:771]
df['FLGND'] = df[1].str[867:868] #death portion starts
df['AGED'] = df[1].str[868:871]
df['AGER5'] = df[1].str[874:875]
df['AGER22'] = df[1].str[875:877]
df['MANNER'] = df[1].str[877:878]
df['DISPO'] = df[1].str[878:879]
df['AUTOPSY'] = df[1].str[879:880]
df['PLACE'] = df[1].str[881:882]
df['UC0D'] = df[1].str[883:887]
df['UCODR130'] = df[1].str[888:891] #130 Infant cause recode
df['RECWT'] = df[1].str[892:900]
df['EANUM'] = df[1].str[902:904] #Number of entity axis conditions
df['ENTITY01'] = df[1].str[904:910]
df['ENTITY02'] = df[1].str[911:917]
df['ENTITY03'] = df[1].str[918:924]
df['ENTITY04'] = df[1].str[925:930]
df['ENTITY05'] = df[1].str[932:938]
df['ENTITY06'] = df[1].str[939:945]
'''
df['ENTITY07'] = df[1].str[946:952]
df['ENTITY08'] = df[1].str[953:959]
df['ENTITY09'] = df[1].str[960:966]
df['ENTITY10'] = df[1].str[967:973]
df['ENTITY11'] = df[1].str[974:980]
df['ENTITY12'] = df[1].str[981:987]
df['ENTITY13'] = df[1].str[988:994]
df['ENTITY14'] = df[1].str[995:1001]
df['ENTITY15'] = df[1].str[1002:1008]
df['ENTITY16'] = df[1].str[1009:1015]
df['ENTITY17'] = df[1].str[1016:1022]
df['ENTITY18'] = df[1].str[1023:1029]
df['ENTITY19'] = df[1].str[1030:1036]
df['ENTITY20'] = df[1].str[1037:1043]
'''
df['RANUM'] = df[1].str[1046:1048]
df['RECORD01'] = df[1].str[1048:1052]
df['RECORD02'] = df[1].str[1053:1057]
df['RECORD03'] = df[1].str[1058:1062]
df['RECORD04'] = df[1].str[1063:1067]
df['RECORD05'] = df[1].str[1068:1072]
df['RECORD06'] = df[1].str[1073:1077]
'''
df['RECORD07'] = df[1].str[1078:1082]
df['RECORD08'] = df[1].str[1083:1087]
df['RECORD09'] = df[1].str[1088:1092]
df['RECORD10'] = df[1].str[1093:1097]
df['RECORD11'] = df[1].str[1098:1102]
df['RECORD12'] = df[1].str[1103:1107]
df['RECORD13'] = df[1].str[1108:1112]
df['RECORD14'] = df[1].str[1113:1117]
df['RECORD15'] = df[1].str[1118:1122]
df['RECORD16'] = df[1].str[1123:1127]
df['RECORD17'] = df[1].str[1128:1132]
df['RECORD18'] = df[1].str[1133:1137]
df['D_RESTATUS'] = df[1].str[1150:1151] #Territory file only
df['STOCCFIPD'] = df[1].str[1151:1153] #Territory file only
df['CNTOCFIPD'] = df[1].str[1153:1156] #Territory file only
df['STRESFIPD'] = df[1].str[1159:1161] #Territory file only
df['DRCNTY'] = df[1].str[1163:1165] #Territory file only
df['CNTYRFPD'] = df[1].str[1165:1168] #Territory file only
df['CNTRSPPD'] = df[1].str[1181:1182] #Territory file only
'''
df['HOSPD'] = df[1].str[1185:1186]
df['WEEKDAYD'] = df[1].str[1186:1187]
df['DTHYR'] = df[1].str[1187:1191]
df['DOD_MM'] = df[1].str[1257:1259]

df = df.drop([1], axis=1)
print(df.columns)
print(df.head())

#df.to_csv('/Users/ateasdale/personal/2019/infantMortality/cdcData/birthCohortLinkedBirthInfantDeath/csvOutput/VS12num.csv', sep=',')
#df.to_csv('/Users/ateasdale/personal/2019/infantMortality/cdcData/birthCohortLinkedBirthInfantDeath/csvOutput/VS11num.csv', sep=',')
# Out:
# Index(['VERSION', 'SEQNUM', 'DOB_YY', 'DOB_MM', 'DOB_WK', 'UBFACIL', 'BFACIL3',
#        'MAGER', 'MAGER14', 'MAGER9',
#        ...
#        'RECORD01', 'RECORD02', 'RECORD03', 'RECORD04', 'RECORD05', 'RECORD06',
#        'HOSPD', 'WEEKDAYD', 'DTHYR', 'DOD_MM'],
#       dtype='object', length=205)
#   VERSION SEQNUM DOB_YY DOB_MM DOB_WK UBFACIL BFACIL3 MAGER MAGER14 MAGER9  \
# 0       S  00001   2011     01      1       1       1    37      11      6
# 1       S  00002   2011     01      7       1       1    20      08      3
# 2       S  00003   2011     01      3       1       1    21      08      3
# 3       S  00004   2011     01      4       1       1    21      08      3
# 4       S  00005   2011     01      7       1       1    22      08      3
#
#    ...   RECORD01 RECORD02 RECORD03 RECORD04 RECORD05 RECORD06 HOSPD WEEKDAYD  \
# 0  ...       A090     P271                                         1        5
# ...
